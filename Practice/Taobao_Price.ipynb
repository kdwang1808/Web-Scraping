# %%
# https://blog.csdn.net/weixin_42482896/article/details/95041994
# https://blog.csdn.net/weixin_43173093/article/details/87716555
import requests
import re

# %%
def getHTMLText(url):
    kv = {'cookie':'miid=1034363887449720171; cna=mOtMFIage0UCATzP7QeTyn+3; thw=cn; cookie2=1d1cdb25967e70f12df64a3d0f944e18; t=24f1a5da416aa8f07af2b70d1dedb889; _tb_token_=e333bee5a3e53; v=0; _m_h5_tk=f2a7697752f00993ef64eff9f2ef8ddb_1573664489317; _m_h5_tk_enc=04469ce82df14e9439869c7b55b01b79; unb=3893552384; uc3=lg2=URm48syIIVrSKA%3D%3D&id2=UNiN%2B0T0i1qETg%3D%3D&nk2=F5RARJdETzbb5A%3D%3D&vt3=F8dByuWlaxk0lwq2wC4%3D; csg=7a6c4484; lgc=tb56897558; cookie17=UNiN%2B0T0i1qETg%3D%3D; dnk=tb56897558; skt=b2aeaaa78ec5d44d; existShop=MTU3MzY1NTU4NA%3D%3D; uc4=nk4=0%40FY4L6MnPA1O%2FG4F08nZCTqIOUMZM&id4=0%40Ug%2BSlGu1w%2BKInEXYx7U2v%2FyCbxXI; tracknick=tb56897558; _cc_=Vq8l%2BKCLiw%3D%3D; tg=0; _l_g_=Ug%3D%3D; sg=84b; _nk_=tb56897558; cookie1=W8rvy9HoGaGD02irNipFHAAbpU3zMviI5H2Gqg7fYz4%3D; mt=ci=0_1; enc=LA%2FhN3hugvaDo9ii0mkQtTT9c5M7IQ%2ByCazkKYbjZGTquZSiqyWj2K9fBnzdjPeVnT1%2Bi7T1Ch8br5enqFwQKQ%3D%3D; alitrackid=www.taobao.com; lastalitrackid=www.taobao.com; hng=CN%7Czh-CN%7CCNY%7C156; uc1=cookie15=UIHiLt3xD8xYTw%3D%3D&cookie14=UoTbnr70o5wCLg%3D%3D; JSESSIONID=61AB1EE855D46C15E83239E5133A935A; l=dBjbh4n7qRknAuKQBOCiZZsCRybOSIRYouWfOsD6i_5CM6Ls3fQOkBKdjFp6VjWftELB4z6vzNp9-etkiKy06Pt-g3fPaxDc.; isg=BLu7T98_Yg6Zcl483ex2OzCtSp8vl0L3wcF2Ua14l7rRDNvuNeBfYtlOIuznKicK',
         'user-agent':'Mozilla/5.0'}
    try:
        #r = requests.get(url, timeout = 30)
        r = requests.get(url, headers=kv, timeout = 30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return ""

# %%
def parsePage(ilt, html):
    try:
        plt = re.findall(r'\"view_price\"\:\"[\d\.]*\"', html)
        tlt = re.findall(r'\"raw_title\"\:\".*?\"', html)
        for i in range(len(plt)):
            price = eval(plt[i].split(':')[1])
            title = eval(tlt[i].split(':')[1])
            ilt.append([price, title])
    except:
        print("")

# %%
def printGoodsList(ilt):
    tplt = "{:4}\t{:8}\t{:16}"
    print(tplt.format("序号", "价格", "商品名称"))
    count = 0
    for g in ilt:
        count = count + 1
        print(tplt.format(count, g[0], g[1]))

# %%
def main():
    goods = '三只松鼠'
    depth = 2
    start_url = 'https://s.taobao.com/search?q=' + goods
    infoList = []
    for i in range(depth):
        try:
            url = start_url + '&s=' + str(44 * i)
            html = getHTMLText(url)
            parsePage(infoList, html)
        except:
            continue
        printGoodsList(infoList)

# %%
main()
# Out:
# 序号  	价格      	商品名称
#    1	138.00  	三只松鼠 坚果大礼包1645g每日坚果送礼零食小吃礼盒9袋装
#    2	44.90   	新货【三只松鼠_碧根果210gx2】零食食品坚果干果山核桃长寿果
#    3	296.00  	满减【三只松鼠_坚果大礼包1645g/9袋】零食每日坚果混合送礼礼盒
#    4	138.00  	三只松鼠 每日坚果750g/30天装混合礼盒送礼零食礼包小包装腰果
#    5	188.00  	三只松鼠巨型零食大礼包30袋超大网红小吃一整箱送女友猪饲料包邮
#    6	59.90   	三只松鼠每日枣夹核桃750g/箱新疆特产大红枣干果零食休闲脆枣
#    7	288.00  	【三只松鼠_坚果大礼包2355g/14袋】零食每日坚果干果送礼礼盒
#    8	146.00  	三只松鼠巨型零食大礼包巨型零食30包
#    9	168.00  	三只松鼠坚果大礼包2188g礼盒
#   10	198.00  	【三只松鼠_巨型零食大礼包3614g/30包】送女友抖音一箱零食
#   11	103.00  	三只松鼠零食大礼包一整箱组合网红女生小吃休闲食品 巨型猪饲料
#   12	118.80  	坚果零食大礼包组合干果混合装三只松鼠一箱整箱送女生超大旗舰店
#   13	99.00   	三只松鼠坚果大礼包整箱散装零食混合装食品干果夏威夷果休闲小吃
#   14	198.00  	【三只松鼠_巨型网红零食礼包3604g】送女友抖音网红一箱零食
#   15	139.00  	三只松鼠_巨型零食大礼包30袋抖音一箱零食组合猪饲料七夕送女友
#   16	69.80   	三只松鼠买一箱送一箱的小零食大礼包女小吃休闲食品散装整箱巨型
#   17	99.00   	三只松鼠零食大礼包肉食类充饥夜宵散装麻辣一箱整箱小吃休闲食品
#   18	67.90   	三只松鼠森林大礼包坚果零食组合套餐超大一箱巨型礼盒混合装30包
#   19	88.80   	【三只松鼠_每日坚果750g/30天装】混合果仁孕妇零食大礼包送礼
#   20	44.70   	三只松鼠坚果组合大礼包零食夏威夷松子开心果碧根果自选旗舰店
# ...
